# %% [markdown]
# **# set设置**

# %% [markdown]
# **1. set_xlim()，set_ylim()**

# %% [markdown]
# * Matplotlib会自动得出沿x、y（和z轴，如果是3D图）轴显示的变量的最小值和最大值。然而，可以通过使用set_xlim()和set_ylim()函数明确地设置限制。

# %%
import matplotlib.pyplot as plt
import numpy as np

# 自动设置轴变量
fig = plt.figure()
a1 = fig.add_axes([0,0,0.7,0.7])
x = np.arange(1,10)
a1.plot(x, np.exp(x))
a1.set_title('exp')
plt.show()

# %%
fig = plt.figure()
a1 = fig.add_axes([0,0,0.7,0.7])
x = np.arange(1,10)

# 在axes区域画图并设置颜色为红色
a1.plot(x, np.exp(x),'r')
a1.set_title('exp')

# 给y轴设置变量范围
a1.set_ylim(0,10000)

# 给x轴设置变量范围
a1.set_xlim(0,10)
plt.show()

# %% [markdown]
# **2. xticks()，yticks()，set_xlabels()，set_ylabels()**

# %% [markdown]
# * ticks是表示轴上数据点的标记。xticks()和yticks()函数使用一个列表对象作为参数。列表中的元素表示相应动作上显示ticks的位置。简单来说，ticks就是轴刻度对应的数。

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

x = np.arange(0, math.pi*2, 0.05)
fig = plt.figure()
ax = fig.add_axes([0, 0, 0.7, 0.7]) # main axes
y = np.sin(x)

ax.plot(x, y)
ax.set_xlabel('angle')
ax.set_title('sine')

ax.set_xticks([0,2,4,6])
# ax.set_xticklabels(['zero','two','four','six'])
ax.set_yticks([-1,0,1])

plt.show()
